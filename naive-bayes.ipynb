# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /Users/elizabethli/cmsc/personal/.venv/lib/python3.9/site-packages (1.1.2)
# Requirement already satisfied: scipy>=1.3.2 in /Users/elizabethli/cmsc/personal/.venv/lib/python3.9/site-packages (from scikit-learn) (1.9.1)
# Requirement already satisfied: numpy>=1.17.3 in /Users/elizabethli/cmsc/personal/.venv/lib/python3.9/site-packages (from scikit-learn) (1.23.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/elizabethli/cmsc/personal/.venv/lib/python3.9/site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in /Users/elizabethli/cmsc/personal/.venv/lib/python3.9/site-packages (from scikit-learn) (1.1.0)
#
# [notice] A new release of pip available: 22.1.2 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import confusion_matrix, classification_report
from scipy.io import mmread
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
test_csv = pd.read_csv('data/Test.csv')
train_csv = pd.read_csv('data/Train.csv')

train_y = train_csv['label']
test_y = test_csv['label']

x_train_tf = mmread('data/x_train_tf.mtx')
x_test_tf = mmread('data/x_test_tf.mtx')

# %%
naive_bayes = MultinomialNB()
naive_bayes.fit(x_train_tf, train_y)

y_pred = naive_bayes.predict(x_test_tf)

# %%
matrix = confusion_matrix(test_y, y_pred)
plt.figure()
sns.heatmap(matrix, annot=True, fmt=".3f", linewidths=.5, square=True, cmap="Greens_r")
plt.ylabel('Actual class')
plt.xlabel('Predicted class')
plt.title('Naive Bayes', size=12)
plt.show()

# %%
scores = classification_report(test_y, y_pred)
print(scores)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.88      0.87      2495
#            1       0.88      0.86      0.87      2505
#
#     accuracy                           0.87      5000
#    macro avg       0.87      0.87      0.87      5000
# weighted avg       0.87      0.87      0.87      5000
